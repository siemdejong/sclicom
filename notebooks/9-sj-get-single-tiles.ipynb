# %%
import os
import shutil

from dpat.data import PMCHHGImageDataset

# %%
d = PMCHHGImageDataset(
    root_dir="/home/sdejong/pmchhg/images-tif",
    image_paths_and_targets="/home/sdejong/pmchhg/images-tif/splits_with_locations/medulloblastoma+pilocytic-astrocytoma_pmchhg_train-subfold-0-fold-0.csv",
    mask_factory="load_from_disk",
    mask_root_dir="/home/sdejong/pmchhg/masks",
)

# %%
x = 7400
d[x][0]
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
d[x][0].save(f"outputs/9/{x}.png")
