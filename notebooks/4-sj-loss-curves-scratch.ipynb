# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(['ipynb', "use_mathtext", "colorsblind10"])

# %%
data = pd.read_csv("snellius-simclr-15-3-2023.csv")

# %%
plt.figure(figsize=(6,3))
plt.plot(data["Step"], data["Value"])
plt.ylim([0, 7])
plt.xlim([0,20000])
plt.ylabel("NT Xent Loss")
plt.xlabel("step")
plt.show()
